# %%
import numpy as np
from sympy import *
import random
import matplotlib.pyplot as plt

# %%
import numpy as np
import sympy
from sympy import Symbol

# %%
#방정식을 풀었을 때
t=symbols('t')
r=symbols('r')
x=Function('x')
deq=Eq(x(t).diff(t),r*x(t)-x(t)**2)
dsolve(deq)
# Out:
# Eq(x(t), r*exp(r*(C1 + t))/(exp(r*(C1 + t)) - 1))

# %%
#1번
t=symbols('t')
r=symbols('r')
x=Function('x')
deq=Eq(x(t).diff(t),-1*x(t)-x(t)**2)
dsolve(deq,ics={x(0):2})
# Out:
# Eq(x(t), -2/(3*(2/3 - exp(t))))

# %%
t1=np.linspace(-1,-0.1,10)
f1=[-2/(3*(2/3 - exp(i))) for i in t1] 
plt.plot(t1,f1,'o-')
plt.show()

# %%
#2번
t= symbols('t')
r=symbols('r')
x = Function('x')
deq2=Eq(x(t).diff(t),-1*x(t)-x(t)**2)
dsolve(deq2,ics={x(0):-2})
# Out:
# Eq(x(t), -2/(2 - exp(t)))

# %%
t2=np.linspace(-1,2,10)
f2=[-2/(2 - exp(i)) for i in t2]
plt.plot(t2,f2,'o-')
plt.show()

# %%
#3번
t=symbols('t')
r=symbols('r')
x=Function('x')
deq=Eq(x(t).diff(t),x(t)-x(t)**2)
dsolve(deq, ics={x(0):2})
# Out:
# Eq(x(t), 1/(1 - exp(-t)/2))

# %%
t3=np.linspace(-2,0,10)
f3=[1/(1 - exp(-i)/2) for i in t3]
plt.plot(t3,f3,'o-')
plt.show()

# %%
#4번
t= symbols('t')
r=symbols('r')
x=Function('x')
deq=Eq(x(t).diff(t),x(t)-x(t)**2)
dsolve(deq,ics={x(0):-2})
# Out:
# Eq(x(t), 1/(1 - 3*exp(-t)/2))

# %%
t4=np.linspace(-2,2,10)
f4=[1/(1 - 3*exp(-i)/2) for i in t4]
plt.plot(t4,f4,'o-')
plt.show()

# %%
#1번
from sympy import Symbol, solve 
x=Symbol('x') 
equation = x*(-1-x)
solve(equation)
# Out:
# [-1, 0]

# %%
#2번
from sympy import Symbol, solve 
x=Symbol('x') 
equation = x*(1-x)
solve(equation)
# Out:
# [0, 1]
